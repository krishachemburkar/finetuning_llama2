# %%
# !pip install autotrain-advanced
# !autotrain setup --update-torch
# !pip install huggingface_hub
# Out:
# Collecting autotrain-advanced
#   Downloading autotrain_advanced-0.7.110-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.2 MB/s eta 0:00:00
# Collecting albumentations==1.4.7 (from autotrain-advanced)
#   Downloading albumentations-1.4.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 kB 8.3 MB/s eta 0:00:00
# Collecting codecarbon==2.3.5 (from autotrain-advanced)
#   Downloading codecarbon-2.3.5-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 11.1 MB/s eta 0:00:00
# Collecting datasets[vision]~=2.19.0 (from autotrain-advanced)
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 15.7 MB/s eta 0:00:00
# Collecting evaluate==0.4.1 (from autotrain-advanced)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.4 MB/s eta 0:00:00
# Collecting ipadic==1.0.0 (from autotrain-advanced)
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jiwer==3.0.3 (from autotrain-advanced)
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Collecting joblib==1.4.0 (from autotrain-advanced)
#   Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 30.2 MB/s eta 0:00:00
# Collecting loguru==0.7.2 (from autotrain-advanced)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.5 MB/s eta 0:00:00
# Collecting pandas==2.2.2 (from autotrain-advanced)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.8.1)
# Collecting optuna==3.6.1 (from autotrain-advanced)
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 46.0 MB/s eta 0:00:00
# Collecting Pillow==10.3.0 (from autotrain-advanced)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 42.7 MB/s eta 0:00:00
# Collecting protobuf==4.23.4 (from autotrain-advanced)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 38.4 MB/s eta 0:00:00
# Collecting sacremoses==0.1.1 (from autotrain-advanced)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 70.2 MB/s eta 0:00:00
# Collecting scikit-learn==1.5.0 (from autotrain-advanced)
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 76.9 MB/s eta 0:00:00
# Collecting sentencepiece==0.2.0 (from autotrain-advanced)
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.66.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.66.4)
# Collecting werkzeug==3.0.2 (from autotrain-advanced)
#   Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 31.8 MB/s eta 0:00:00
# Requirement already satisfied: xgboost==2.0.3 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.0.3)
# Requirement already satisfied: huggingface-hub==0.23.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.23.1)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.31.0)
# Collecting einops==0.7.0 (from autotrain-advanced)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.1 MB/s eta 0:00:00
# Collecting invisible-watermark==0.2.0 (from autotrain-advanced)
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging==24.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (24.0)
# Collecting cryptography==42.0.5 (from autotrain-advanced)
#   Downloading cryptography-42.0.5-cp39-abi3-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 105.1 MB/s eta 0:00:00
# Collecting nvitop==1.3.2 (from autotrain-advanced)
#   Downloading nvitop-1.3.2-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.4/215.4 kB 1.2 MB/s eta 0:00:00
# Collecting tensorboard==2.16.2 (from autotrain-advanced)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 107.1 MB/s eta 0:00:00
# Collecting peft==0.11.1 (from autotrain-advanced)
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 35.4 MB/s eta 0:00:00
# Collecting trl==0.8.6 (from autotrain-advanced)
#   Downloading trl-0.8.6-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 36.0 MB/s eta 0:00:00
# Collecting tiktoken==0.6.0 (from autotrain-advanced)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 75.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers==4.41.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.41.0)
# Collecting accelerate==0.30.1 (from autotrain-advanced)
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 42.3 MB/s eta 0:00:00
# Collecting diffusers==0.27.2 (from autotrain-advanced)
#   Downloading diffusers-0.27.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 105.4 MB/s eta 0:00:00
# Collecting rouge-score==0.1.2 (from autotrain-advanced)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting py7zr==0.21.0 (from autotrain-advanced)
#   Downloading py7zr-0.21.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.9 MB/s eta 0:00:00
# Collecting fastapi==0.111.0 (from autotrain-advanced)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.4 MB/s eta 0:00:00
# Collecting uvicorn==0.29.0 (from autotrain-advanced)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.9 MB/s eta 0:00:00
# Collecting python-multipart==0.0.9 (from autotrain-advanced)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: pydantic==2.7.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.7.1)
# Collecting hf-transfer (from autotrain-advanced)
#   Downloading hf_transfer-0.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 84.1 MB/s eta 0:00:00
# Collecting pyngrok==7.1.6 (from autotrain-advanced)
#   Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Collecting authlib==1.3.0 (from autotrain-advanced)
#   Downloading Authlib-1.3.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous==2.2.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.2.0)
# Collecting seqeval==1.2.2 (from autotrain-advanced)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.27.0 (from autotrain-advanced)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml==6.0.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (6.0.1)
# Collecting timm==1.0.3 (from autotrain-advanced)
#   Downloading timm-1.0.3-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.9 MB/s eta 0:00:00
# Collecting torchmetrics==1.4.0 (from autotrain-advanced)
#   Downloading torchmetrics-1.4.0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools==2.0.7 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.0.7)
# Collecting bitsandbytes==0.43.1 (from autotrain-advanced)
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->autotrain-advanced) (1.25.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->autotrain-advanced) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->autotrain-advanced) (2.3.0+cu121)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->autotrain-advanced) (0.4.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.7->autotrain-advanced) (1.11.4)
# Collecting scikit-image>=0.21.0 (from albumentations==1.4.7->autotrain-advanced)
#   Downloading scikit_image-0.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.7->autotrain-advanced) (4.11.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.7->autotrain-advanced) (4.9.0.80)
# Collecting arrow (from codecarbon==2.3.5->autotrain-advanced)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.4 MB/s eta 0:00:00
# Collecting pynvml (from codecarbon==2.3.5->autotrain-advanced)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.3.5->autotrain-advanced) (9.0.0)
# Collecting rapidfuzz (from codecarbon==2.3.5->autotrain-advanced)
#   Downloading rapidfuzz-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 88.5 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.3.5->autotrain-advanced) (8.1.7)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.3.5->autotrain-advanced) (0.20.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography==42.0.5->autotrain-advanced) (1.16.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->autotrain-advanced) (7.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->autotrain-advanced) (3.14.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->autotrain-advanced) (2023.12.25)
# Collecting dill (from evaluate==0.4.1->autotrain-advanced)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.1 MB/s eta 0:00:00
# Collecting xxhash (from evaluate==0.4.1->autotrain-advanced)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.8 MB/s eta 0:00:00
# Collecting multiprocess (from evaluate==0.4.1->autotrain-advanced)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.1->autotrain-advanced) (2023.6.0)
# Collecting responses<0.19 (from evaluate==0.4.1->autotrain-advanced)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi==0.111.0->autotrain-advanced)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.6 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi==0.111.0->autotrain-advanced)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->autotrain-advanced) (3.1.4)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi==0.111.0->autotrain-advanced)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.9 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi==0.111.0->autotrain-advanced)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 23.0 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi==0.111.0->autotrain-advanced)
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->autotrain-advanced) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->autotrain-advanced) (2024.2.2)
# Collecting httpcore==1.* (from httpx==0.27.0->autotrain-advanced)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->autotrain-advanced) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (1.6.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (4.8.0.76)
# Collecting nvidia-ml-py<12.536.0a0,>=11.450.51 (from nvitop==1.3.2->autotrain-advanced)
#   Downloading nvidia_ml_py-12.535.161-py3-none-any.whl (37 kB)
# Requirement already satisfied: cachetools>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from nvitop==1.3.2->autotrain-advanced) (5.3.3)
# Requirement already satisfied: termcolor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nvitop==1.3.2->autotrain-advanced) (2.4.0)
# Collecting alembic>=1.5.0 (from optuna==3.6.1->autotrain-advanced)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 31.3 MB/s eta 0:00:00
# Collecting colorlog (from optuna==3.6.1->autotrain-advanced)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.6.1->autotrain-advanced) (2.0.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->autotrain-advanced) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->autotrain-advanced) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->autotrain-advanced) (2024.1)
# Collecting texttable (from py7zr==0.21.0->autotrain-advanced)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 100.3 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading pyzstd-0.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.8/413.8 kB 49.0 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 21.8 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 8.8 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.8 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr==0.21.0->autotrain-advanced)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 108.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools==2.0.7->autotrain-advanced) (3.7.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.1->autotrain-advanced) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.1->autotrain-advanced) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2.0.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.0->autotrain-advanced) (3.5.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.16.2->autotrain-advanced) (1.64.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.16.2->autotrain-advanced) (3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.16.2->autotrain-advanced) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.16.2->autotrain-advanced) (0.7.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==1.0.3->autotrain-advanced) (0.18.0+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics==1.4.0->autotrain-advanced)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Collecting pretty-errors==1.2.25 (from torchmetrics==1.4.0->autotrain-advanced)
#   Downloading pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.0->autotrain-advanced) (0.19.1)
# Collecting tyro>=0.5.11 (from trl==0.8.6->autotrain-advanced)
#   Downloading tyro-0.8.4-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 17.4 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug==3.0.2->autotrain-advanced) (2.1.5)
# Collecting colorama (from pretty-errors==1.2.25->torchmetrics==1.4.0->autotrain-advanced)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.19.0->autotrain-advanced) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.19.0->autotrain-advanced) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.19.0->autotrain-advanced) (3.9.5)
# Collecting Mako (from alembic>=1.5.0->optuna==3.6.1->autotrain-advanced)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography==42.0.5->autotrain-advanced) (2.22)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi==0.111.0->autotrain-advanced)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 32.5 MB/s eta 0:00:00
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi==0.111.0->autotrain-advanced)
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.19.0->autotrain-advanced) (4.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->autotrain-advanced) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->autotrain-advanced) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->autotrain-advanced) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.7->autotrain-advanced) (3.1.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.7->autotrain-advanced) (3.3)
# Collecting imageio>=2.33 (from scikit-image>=0.21.0->albumentations==1.4.7->autotrain-advanced)
#   Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 43.4 MB/s eta 0:00:00
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.7->autotrain-advanced) (2024.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.7->autotrain-advanced) (0.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna==3.6.1->autotrain-advanced) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.27.0->autotrain-advanced) (1.2.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced) (1.12)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.30.1->autotrain-advanced) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.30.1->autotrain-advanced)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 74.4 MB/s eta 0:00:00
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.8.6->autotrain-advanced) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.8.6->autotrain-advanced) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl==0.8.6->autotrain-advanced)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Collecting httptools>=0.5.0 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 44.6 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 61.4 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 88.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn==0.29.0->autotrain-advanced)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 20.5 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon==2.3.5->autotrain-advanced)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.27.2->autotrain-advanced) (3.18.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.6->autotrain-advanced) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.6->autotrain-advanced) (2.16.1)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi==0.111.0->autotrain-advanced)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.30.1->autotrain-advanced) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.8.6->autotrain-advanced) (0.1.2)
# Building wheels for collected packages: ipadic, rouge-score, seqeval
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=fc1a2297bdc579ba70eddf3aadf2c40da4da85305bc25500d50c9c661e07bb89
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=befa6475a630a83e4d77f945f9c52c95bf172e9758befcac6b7d916b8fd58a16
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=b556588a8f4cd7a5102b7914a4ad09c16642ed0fa7c5c726b343915b5fe2a717
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built ipadic rouge-score seqeval
# Installing collected packages: texttable, sentencepiece, nvidia-ml-py, ipadic, brotli, xxhash, werkzeug, websockets, uvloop, ujson, types-python-dateutil, shtab, shellingham, rapidfuzz, pyzstd, python-multipart, python-dotenv, pyppmd, pynvml, pyngrok, pycryptodomex, pybcj, protobuf, Pillow, orjson, nvitop, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, multivolumefile, Mako, loguru, lightning-utilities, joblib, inflate64, httptools, hf-transfer, h11, einops, dnspython, dill, colorlog, colorama, watchfiles, uvicorn, tiktoken, tensorboard, starlette, scikit-learn, sacremoses, responses, py7zr, pretty-errors, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, jiwer, imageio, httpcore, email_validator, cryptography, arrow, alembic, tyro, typer, seqeval, scikit-image, rouge-score, optuna, nvidia-cusolver-cu12, httpx, diffusers, codecarbon, authlib, fastapi-cli, datasets, albumentations, torchmetrics, invisible-watermark, fastapi, evaluate, bitsandbytes, accelerate, trl, timm, peft, autotrain-advanced
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.99
#     Uninstalling sentencepiece-0.1.99:
#       Successfully uninstalled sentencepiece-0.1.99
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.3
#     Uninstalling Werkzeug-3.0.3:
#       Successfully uninstalled Werkzeug-3.0.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Successfully uninstalled imageio-2.31.6
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.7
#     Uninstalling cryptography-42.0.7:
#       Successfully uninstalled cryptography-42.0.7
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.3.1
#     Uninstalling albumentations-1.3.1:
#       Successfully uninstalled albumentations-1.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.16.2 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.23.4 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# Successfully installed Mako-1.3.5 Pillow-10.3.0 accelerate-0.30.1 albumentations-1.4.7 alembic-1.13.1 arrow-1.3.0 authlib-1.3.0 autotrain-advanced-0.7.110 bitsandbytes-0.43.1 brotli-1.1.0 codecarbon-2.3.5 colorama-0.4.6 colorlog-6.8.2 cryptography-42.0.5 datasets-2.19.1 diffusers-0.27.2 dill-0.3.8 dnspython-2.6.1 einops-0.7.0 email_validator-2.1.1 evaluate-0.4.1 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 hf-transfer-0.1.6 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 imageio-2.34.1 inflate64-1.0.0 invisible-watermark-0.2.0 ipadic-1.0.0 jiwer-3.0.3 joblib-1.4.0 lightning-utilities-0.11.2 loguru-0.7.2 multiprocess-0.70.16 multivolumefile-0.2.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-ml-py-12.535.161 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 nvitop-1.3.2 optuna-3.6.1 orjson-3.10.3 pandas-2.2.2 peft-0.11.1 pretty-errors-1.2.25 protobuf-4.23.4 py7zr-0.21.0 pybcj-1.0.2 pycryptodomex-3.20.0 pyngrok-7.1.6 pynvml-11.5.0 pyppmd-1.1.0 python-dotenv-1.0.1 python-multipart-0.0.9 pyzstd-0.16.0 rapidfuzz-3.9.1 responses-0.18.0 rouge-score-0.1.2 sacremoses-0.1.1 scikit-image-0.23.2 scikit-learn-1.5.0 sentencepiece-0.2.0 seqeval-1.2.2 shellingham-1.5.4 shtab-1.7.1 starlette-0.37.2 tensorboard-2.16.2 texttable-1.7.0 tiktoken-0.6.0 timm-1.0.3 torchmetrics-1.4.0 trl-0.8.6 typer-0.12.3 types-python-dateutil-2.9.0.20240316 tyro-0.8.4 ujson-5.10.0 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0 werkzeug-3.0.2 xxhash-3.4.1
# INFO     | 2024-05-28 07:10:52 | autotrain.cli.run_setup:run:43 - Installing latest xformers
# INFO     | 2024-05-28 07:10:53 | autotrain.cli.run_setup:run:45 - Successfully installed latest xformers
# INFO     | 2024-05-28 07:10:53 | autotrain.cli.run_setup:run:51 - Installing latest PyTorch
# INFO     | 2024-05-28 07:10:59 | autotrain.cli.run_setup:run:53 - Successfully installed latest PyTorch
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.2.2)

# %%
from huggingface_hub import notebook_login
notebook_login()
# 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
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead, AutoModelForCausalLM
import torch
import os

# %%
# !autotrain llm --train -help
# Out:
# usage: autotrain <command> [<args>] llm [-h] [--train] [--deploy] [--inference]
#                                         [--username USERNAME]
#                                         [--backend {spaces-a10g-large,spaces-a10g-small,spaces-a100-large,spaces-t4-medium,spaces-t4-small,spaces-cpu-upgrade,spaces-cpu-basic,spaces-l4x1,spaces-l4x4,spaces-a10g-largex2,spaces-a10g-largex4,dgx-a100,dgx-2a100,dgx-4a100,dgx-8a100,ep-aws-useast1-s,ep-aws-useast1-m,ep-aws-useast1-l,ep-aws-useast1-xl,ep-aws-useast1-2xl,ep-aws-useast1-4xl,ep-aws-useast1-8xl,nvcf-l40sx1,nvcf-h100x1,nvcf-h100x2,nvcf-h100x4,nvcf-h100x8,local-ui,local,local-cli}]
#                                         [--token TOKEN] [--push-to-hub] --model MODEL
#                                         --project-name PROJECT_NAME [--data-path DATA_PATH]
#                                         [--train-split TRAIN_SPLIT] [--valid-split VALID_SPLIT]
#                                         [--batch-size BATCH_SIZE] [--seed SEED] [--epochs EPOCHS]
#                                         [--gradient-accumulation GRADIENT_ACCUMULATION]
#                                         [--disable-gradient-checkpointing] [--lr LR]
#                                         [--log {none,wandb,tensorboard}]
#                                         [--text_column TEXT_COLUMN]
#                                         [--rejected_text_column REJECTED_TEXT_COLUMN]
#                                         [--prompt_text_column PROMPT_TEXT_COLUMN]
#                                         [--model-ref MODEL_REF] [--warmup_ratio WARMUP_RATIO]
#                                         [--optimizer OPTIMIZER] [--scheduler SCHEDULER]
#                                         [--weight_decay WEIGHT_DECAY]
#                                         [--max_grad_norm MAX_GRAD_NORM] [--add_eos_token]
#                                         [--block_size BLOCK_SIZE] [--peft] [--lora_r LORA_R]
#                                         [--lora_alpha LORA_ALPHA] [--lora_dropout LORA_DROPOUT]
#                                         [--logging_steps LOGGING_STEPS]
#                                         [--evaluation_strategy {epoch,steps,no}]
#                                         [--save_total_limit SAVE_TOTAL_LIMIT]
#                                         [--auto_find_batch_size]
#                                         [--mixed_precision {fp16,bf16,None}]
#                                         [--quantization {int4,int8,None}]
#                                         [--model_max_length MODEL_MAX_LENGTH]
#                                         [--max_prompt_length MAX_PROMPT_LENGTH]
#                                         [--max_completion_length MAX_COMPLETION_LENGTH]
#                                         [--trainer {default,dpo,sft,orpo,reward}]
#                                         [--target_modules TARGET_MODULES] [--merge_adapter]
#                                         [--use_flash_attention_2] [--dpo-beta DPO_BETA]
#                                         [--chat_template {tokenizer,chatml,zephyr,None}]
#                                         [--padding {left,right,None}]
# autotrain <command> [<args>] llm: error: argument -h/--help: ignored explicit argument 'elp'

# %%
# !autotrain llm --train --project-name ntwst-krisha --model meta-llama/Llama-2-7b-chat-hf --data-path /content/data --quantization int4 --use-peft --lr 1e-5 --train-batch-size 2 --epochs 1 --trainer sft --model_max_length 1024
# Out:
# INFO     | 2024-05-28 07:44:49 | autotrain.cli.run_llm:run:344 - Running LLM
# WARNING  | 2024-05-28 07:44:49 | autotrain.trainers.common:__init__:180 - Parameters supplied but not used: train, deploy, backend, version, func, config, inference
# Saving the dataset (1/1 shards): 100% 5180/5180 [00:00<00:00, 421578.99 examples/s]
# Saving the dataset (1/1 shards): 100% 5180/5180 [00:00<00:00, 420062.93 examples/s]
# INFO     | 2024-05-28 07:44:50 | autotrain.backends.local:create:8 - Starting local training...
# INFO     | 2024-05-28 07:44:50 | autotrain.commands:launch_command:372 - ['accelerate', 'launch', '--num_machines', '1', '--num_processes', '1', '--mixed_precision', 'no', '-m', 'autotrain.trainers.clm', '--training_config', 'ntwst-krisha/training_params.json']
# INFO     | 2024-05-28 07:44:50 | autotrain.commands:launch_command:373 - {'model': 'meta-llama/Llama-2-7b-chat-hf', 'project_name': 'ntwst-krisha', 'data_path': 'ntwst-krisha/autotrain-data', 'train_split': 'train', 'valid_split': None, 'add_eos_token': False, 'block_size': -1, 'model_max_length': 1024, 'padding': None, 'trainer': 'sft', 'use_flash_attention_2': False, 'log': 'none', 'disable_gradient_checkpointing': False, 'logging_steps': -1, 'evaluation_strategy': 'epoch', 'save_total_limit': 1, 'auto_find_batch_size': False, 'mixed_precision': None, 'lr': 1e-05, 'epochs': 1, 'batch_size': 2, 'warmup_ratio': 0.1, 'gradient_accumulation': 1, 'optimizer': 'adamw_torch', 'scheduler': 'linear', 'weight_decay': 0.0, 'max_grad_norm': 1.0, 'seed': 42, 'chat_template': None, 'quantization': 'int4', 'target_modules': 'all-linear', 'merge_adapter': False, 'peft': True, 'lora_r': 16, 'lora_alpha': 32, 'lora_dropout': 0.05, 'model_ref': None, 'dpo_beta': 0.1, 'max_prompt_length': 128, 'max_completion_length': None, 'prompt_text_column': 'autotrain_prompt', 'text_column': 'autotrain_text', 'rejected_text_column': 'autotrain_rejected_text', 'push_to_hub': False, 'username': None, 'token': None}
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# INFO     | 2024-05-28 07:45:01 | autotrain.trainers.clm.train_clm_sft:train:14 - Starting SFT training...
# INFO     | 2024-05-28 07:45:01 | autotrain.trainers.clm.utils:process_input_data:329 - loading dataset from disk
# INFO     | 2024-05-28 07:45:01 | autotrain.trainers.clm.utils:process_input_data:388 - Train data: Dataset({
#     features: ['autotrain_text'],
#     num_rows: 5180
# })
# INFO     | 2024-05-28 07:45:01 | autotrain.trainers.clm.utils:process_input_data:389 - Valid data: None
# tokenizer_config.json: 100% 1.62k/1.62k [00:00<00:00, 9.33MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 15.4MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 10.7MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.77MB/s]
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.utils:configure_logging_steps:461 - configuring logging steps
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.utils:configure_logging_steps:474 - Logging steps: 25
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.utils:configure_training_args:479 - configuring training args
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.utils:configure_block_size:542 - Using block size 1024
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.train_clm_sft:train:27 - loading model config...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 614/614 [00:00<00:00, 4.87MB/s]
# INFO     | 2024-05-28 07:45:02 | autotrain.trainers.clm.train_clm_sft:train:35 - loading model...
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json: 100% 26.8k/26.8k [00:00<00:00, 101MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/9.98G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/9.98G [00:00<01:36, 103MB/s]
# model-00001-of-00002.safetensors:   0% 41.9M/9.98G [00:00<00:47, 207MB/s]
# model-00001-of-00002.safetensors:   1% 83.9M/9.98G [00:00<00:34, 283MB/s]
# model-00001-of-00002.safetensors:   1% 126M/9.98G [00:00<00:33, 296MB/s]
# model-00001-of-00002.safetensors:   2% 157M/9.98G [00:00<00:36, 271MB/s]
# model-00001-of-00002.safetensors:   2% 199M/9.98G [00:00<00:34, 287MB/s]
# model-00001-of-00002.safetensors:   2% 241M/9.98G [00:00<00:32, 297MB/s]
# model-00001-of-00002.safetensors:   3% 273M/9.98G [00:00<00:33, 290MB/s]
# model-00001-of-00002.safetensors:   3% 304M/9.98G [00:01<00:32, 293MB/s]
# model-00001-of-00002.safetensors:   3% 336M/9.98G [00:01<00:33, 291MB/s]
# model-00001-of-00002.safetensors:   4% 367M/9.98G [00:01<00:32, 295MB/s]
# model-00001-of-00002.safetensors:   4% 398M/9.98G [00:01<00:32, 296MB/s]
# model-00001-of-00002.safetensors:   4% 430M/9.98G [00:01<00:32, 292MB/s]
# model-00001-of-00002.safetensors:   5% 461M/9.98G [00:01<00:32, 294MB/s]
[00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   1% 41.9M/3.50G [00:00<00:09, 384MB/s]
# model-00002-of-00002.safetensors:   2% 83.9M/3.50G [00:00<00:10, 317MB/s]
# model-00002-of-00002.safetensors:   4% 126M/3.50G [00:00<00:10, 320MB/s]
# model-00002-of-00002.safetensors:   5% 168M/3.50G [00:00<00:10, 314MB/s]
# model-00002-of-00002.safetensors:   6% 210M/3.50G [00:00<00:10, 304MB/s]
# model-00002-of-00002.safetensors:   7% 241M/3.50G [00:00<00:10, 302MB/s]
# model-00002-of-00002.safetensors:   8% 283M/3.50G [00:00<00:10, 300MB/s]
# model-00002-of-00002.safetensors:   9% 315M/3.50G [00:01<00:10, 302MB/s]
# model-00002-of-00002.safetensors:  10% 357M/3.50G [00:01<00:10, 307MB/s]
# model-00002-of-00002.safetensors:  11% 398M/3.50G [00:01<00:09, 310MB/s]
# model-00002-of-00002.safetensors:  12% 430M/3.50G [00:01<00:09, 308MB/s]
# model-00002-of-00002.safetensors:  13% 472M/3.50G [00:01<00:09, 311MB/s]
# model-00002-of-00002.safetensors:  14% 503M/3.50G [00:01<00:09, 307MB/s]
# model-00002-of-00002.safetensors:  15% 535M/3.50G [00:01<00:09, 309MB/s]
# model-00002-of-00002.safetensors:  16% 566M/3.50G [00:01<00:10, 280MB/s]
# model-00002-of-00002.safetensors:  17% 598M/3.50G [00:02<00:11, 256MB/s]
# model-00002-of-00002.safetensors:  18% 629M/3.50G [00:02<00:12, 234MB/s]
# model-00002-of-00002.safetensors:  19% 661M/3.50G [00:02<00:12, 220MB/s]
# model-00002-of-00002.safetensors:  20% 692M/3.50G [00:02<00:13, 202MB/s]
# model-00002-of-00002.safetensors:  20% 713M/3.50G [00:02<00:14, 196MB/s]
# model-00002-of-00002.safetensors:  21% 734M/3.50G [00:02<00:14, 197MB/s]
# model-00002-of-00002.safetensors:  22% 765M/3.50G [00:02<00:12, 225MB/s]
# model-00002-of-00002.safetensors:  23% 797M/3.50G [00:02<00:11, 237MB/s]
# model-00002-of-00002.safetensors:  24% 839M/3.50G [00:03<00:10, 264MB/s]
# model-00002-of-00002.safetensors:  25% 870M/3.50G [00:03<00:09, 276MB/s]
# model-00002-of-00002.safetensors:  26% 902M/3.50G [00:03<00:09, 271MB/s]
# model-00002-of-00002.safetensors:  27% 944M/3.50G [00:03<00:08, 288MB/s]
# model-00002-of-00002.safetensors:  28% 975M/3.50G [00:03<00:08, 291MB/s]
# model-00002-of-00002.safetensors:  29% 1.02G/3.50G [00:03<00:08, 304MB/s]
# model-00002-of-00002.safetensors:  30% 1.06G/3.50G [00:03<00:08, 280MB/s]
# model-00002-of-00002.safetensors:  31% 1.09G/3.50G [00:04<00:09, 253MB/s]
# model-00002-of-00002.safetensors:  32% 1.12G/3.50G [00:04<00:10, 226MB/s]
# model-00002-of-00002.safetensors:  33% 1.15G/3.50G [00:04<00:11, 213MB/s]
# model-00002-of-00002.safetensors:  34% 1.18G/3.50G [00:04<00:10, 219MB/s]
# model-00002-of-00002.safetensors:  35% 1.22G/3.50G [00:04<00:10, 228MB/s]
# model-00002-of-00002.safetensors:  36% 1.25G/3.50G [00:04<00:09, 232MB/s]
# model-00002-of-00002.safetensors:  37% 1.28G/3.50G [00:04<00:09, 241MB/s]
# model-00002-of-00002.safetensors:  37% 1.31G/3.50G [00:04<00:08, 245MB/s]
# model-00002-of-00002.safetensors:  38% 1.34G/3.50G [00:05<00:08, 252MB/s]
# model-00002-of-00002.safetensors:  39% 1.37G/3.50G [00:05<00:08, 256MB/s]
# model-00002-of-00002.safetensors:  40% 1.41G/3.50G [00:05<00:08, 254MB/s]
# model-00002-of-00002.safetensors:  41% 1.44G/3.50G [00:05<00:08, 252MB/s]
# model-00002-of-00002.safetensors:  42% 1.47G/3.50G [00:05<00:08, 250MB/s]
# model-00002-of-00002.safetensors:  43% 1.50G/3.50G [00:05<00:07, 256MB/s]
# model-00002-of-00002.safetensors:  44% 1.53G/3.50G [00:05<00:07, 256MB/s]
# model-00002-of-00002.safetensors:  45% 1.56G/3.50G [00:05<00:07, 252MB/s]
# model-00002-of-00002.safetensors:  46% 1.59G/3.50G [00:06<00:07, 260MB/s]
# model-00002-of-00002.safetensors:  46% 1.63G/3.50G [00:06<00:07, 257MB/s]
# model-00002-of-00002.safetensors:  47% 1.66G/3.50G [00:06<00:07, 255MB/s]
# model-00002-of-00002.safetensors:  48% 1.69G/3.50G [00:06<00:07, 246MB/s]
# model-00002-of-00002.safetensors:  49% 1.72G/3.50G [00:06<00:07, 245MB/s]
# model-00002-of-00002.safetensors:  50% 1.75G/3.50G [00:06<00:07, 248MB/s]
# model-00002-of-00002.safetensors:  51% 1.78G/3.50G [00:06<00:06, 253MB/s]
# model-00002-of-00002.safetensors:  52% 1.81G/3.50G [00:06<00:06, 252MB/s]
# model-00002-of-00002.safetensors:  53% 1.85G/3.50G [00:07<00:06, 253MB/s]
# model-00002-of-00002.safetensors:  54% 1.88G/3.50G [00:07<00:06, 253MB/s]
# model-00002-of-00002.safetensors:  55% 1.91G/3.50G [00:07<00:06, 253MB/s]
# model-00002-of-00002.safetensors:  55% 1.94G/3.50G [00:07<00:06, 259MB/s]
# model-00002-of-00002.safetensors:  56% 1.97G/3.50G [00:07<00:06, 245MB/s]
# model-00002-of-00002.safetensors:  57% 2.00G/3.50G [00:07<00:06, 241MB/s]
# model-00002-of-00002.safetensors:  58% 2.03G/3.50G [00:08<00:08, 170MB/s]
# model-00002-of-00002.safetensors:  59% 2.07G/3.50G [00:08<00:07, 190MB/s]
# model-00002-of-00002.safetensors:  60% 2.10G/3.50G [00:08<00:06, 213MB/s]
# model-00002-of-00002.safetensors:  61% 2.14G/3.50G [00:08<00:05, 243MB/s]
# model-00002-of-00002.safetensors:  62% 2.18G/3.50G [00:08<00:04, 270MB/s]
# model-00002-of-00002.safetensors:  64% 2.22G/3.50G [00:08<00:04, 291MB/s]
# model-00002-of-00002.safetensors:  64% 2.25G/3.50G [00:08<00:04, 290MB/s]
# model-00002-of-00002.safetensors:  65% 2.29G/3.50G [00:08<00:04, 294MB/s]
# model-00002-of-00002.safetensors:  66% 2.32G/3.50G [00:08<00:04, 295MB/s]
# model-00002-of-00002.safetensors:  67% 2.36G/3.50G [00:09<00:03, 305MB/s]
# model-00002-of-00002.safetensors:  68% 2.39G/3.50G [00:09<00:03, 294MB/s]
# model-00002-of-00002.safetensors:  69% 2.43G/3.50G [00:09<00:03, 314MB/s]
# model-00002-of-00002.safetensors:  71% 2.47G/3.50G [00:09<00:03, 301MB/s]
# model-00002-of-00002.safetensors:  72% 2.51G/3.50G [00:09<00:03, 280MB/s]
# model-00002-of-00002.safetensors:  72% 2.54G/3.50G [00:09<00:03, 263MB/s]
# model-00002-of-00002.safetensors:  73% 2.57G/3.50G [00:09<00:03, 263MB/s]
# model-00002-of-00002.safetensors:  74% 2.60G/3.50G [00:10<00:03, 257MB/s]
# model-00002-of-00002.safetensors:  75% 2.63G/3.50G [00:10<00:03, 245MB/s]
# model-00002-of-00002.safetensors:  76% 2.66G/3.50G [00:10<00:03, 236MB/s]
# model-00002-of-00002.safetensors:  77% 2.69G/3.50G [00:10<00:03, 225MB/s]
# model-00002-of-00002.safetensors:  78% 2.73G/3.50G [00:10<00:03, 215MB/s]
# model-00002-of-00002.safetensors:  79% 2.76G/3.50G [00:10<00:03, 221MB/s]
# model-00002-of-00002.safetensors:  80% 2.79G/3.50G [00:10<00:03, 224MB/s]
# model-00002-of-00002.safetensors:  81% 2.82G/3.50G [00:11<00:02, 229MB/s]
# model-00002-of-00002.safetensors:  81% 2.85G/3.50G [00:11<00:02, 221MB/s]
# model-00002-of-00002.safetensors:  82% 2.88G/3.50G [00:11<00:02, 220MB/s]
# model-00002-of-00002.safetensors:  83% 2.92G/3.50G [00:11<00:02, 227MB/s]
# model-00002-of-00002.safetensors:  84% 2.95G/3.50G [00:11<00:02, 227MB/s]
# model-00002-of-00002.safetensors:  85% 2.98G/3.50G [00:11<00:02, 223MB/s]
# model-00002-of-00002.safetensors:  86% 3.01G/3.50G [00:11<00:02, 232MB/s]
# model-00002-of-00002.safetensors:  87% 3.04G/3.50G [00:12<00:02, 223MB/s]
# model-00002-of-00002.safetensors:  88% 3.07G/3.50G [00:12<00:02, 212MB/s]
# model-00002-of-00002.safetensors:  89% 3.10G/3.50G [00:12<00:01, 205MB/s]
# model-00002-of-00002.safetensors:  89% 3.12G/3.50G [00:13<00:04, 76.1MB/s]
# model-00002-of-00002.safetensors:  90% 3.17G/3.50G [00:13<00:03, 108MB/s]
# model-00002-of-00002.safetensors:  91% 3.20G/3.50G [00:13<00:02, 134MB/s]
# model-00002-of-00002.safetensors:  92% 3.23G/3.50G [00:13<00:01, 149MB/s]
# model-00002-of-00002.safetensors:  93% 3.26G/3.50G [00:13<00:01, 170MB/s]
# model-00002-of-00002.safetensors:  94% 3.29G/3.50G [00:13<00:01, 188MB/s]
# model-00002-of-00002.safetensors:  95% 3.32G/3.50G [00:13<00:00, 211MB/s]
# model-00002-of-00002.safetensors:  96% 3.36G/3.50G [00:14<00:00, 223MB/s]
# model-00002-of-00002.safetensors:  97% 3.40G/3.50G [00:14<00:00, 258MB/s]
# model-00002-of-00002.safetensors:  98% 3.44G/3.50G [00:14<00:00, 290MB/s]
# model-00002-of-00002.safetensors: 100% 3.50G/3.50G [00:14<00:00, 240MB/s]
# Downloading shards: 100% 2/2 [01:06<00:00, 33.42s/it]
# Loading checkpoint shards: 100% 2/2 [00:55<00:00, 27.85s/it]
# generation_config.json: 100% 188/188 [00:00<00:00, 1.23MB/s]
# INFO     | 2024-05-28 07:47:07 | autotrain.trainers.clm.train_clm_sft:train:66 - model dtype: torch.float16
# INFO     | 2024-05-28 07:47:07 | autotrain.trainers.clm.train_clm_sft:train:79 - creating trainer
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Generating train split: 0 examples [00:00, ? examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (2386 > 1024). Running this sequence through the model will result in indexing errors
# Generating train split: 5747 examples [00:07, 815.73 examples/s]
# INFO     | 2024-05-28 07:47:15 | autotrain.trainers.common:on_train_begin:231 - Starting to train...
#   0% 3/2874 [01:12<19:20:27, 24.25s/it]Traceback (most recent call last):
#   File "/usr/lib/python3.10/subprocess.py", line 1209, in wait
#     return self._wait(timeout=timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1959, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.10/subprocess.py", line 1917, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/autotrain", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/cli/autotrain.py", line 64, in main
#     command.run()
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/cli/run_llm.py", line 349, in run
#     job_id = project.create()
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/project.py", line 57, in create
#     return runner.create()
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/backends/local.py", line 11, in create
#     training_pid = run_training(params, task_id, local=True, wait=self.wait)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/utils.py", line 54, in run_training
#     process.wait()
#   File "/usr/lib/python3.10/subprocess.py", line 1222, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1953, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/accelerate_cli.py", line 46, in main
#     args.func(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 1082, in launch_command
#     simple_launcher(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 685, in simple_launcher
#     process.wait()
#   File "/usr/lib/python3.10/subprocess.py", line 1209, in wait
#     return self._wait(timeout=timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1959, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.10/subprocess.py", line 1917, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/clm/__main__.py", line 53, in <module>
#     train(_config)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/common.py", line 117, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/clm/__main__.py", line 28, in train
#     train_sft(config)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/clm/train_clm_sft.py", line 98, in train
#     trainer.train()
#   File "/usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py", line 361, in train
#     output = super().train(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/trainer.py", line 1885, in train
#     return inner_training_loop(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/trainer.py", line 2216, in _inner_training_loop
#     tr_loss_step = self.training_step(model, inputs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/trainer.py", line 3250, in training_step
#     self.accelerator.backward(loss)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py", line 2125, in backward
#     loss.backward(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
#   0% 3/2874 [01:36<25:34:14, 32.06s/it]

# %%
# finetuned_tokenizer = AutoTokenizer.from_pretrained("/content/ntwst-krisha")
# finetuned_model = AutoModelForCausalLM.from_pretrained("/content/ntwst-krisha")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-462f5b26a0bc> in <cell line: 1>()
# ----> 1 finetuned_tokenizer = AutoTokenizer.from_pretrained("/content/ntwst-krisha")
#       2 finetuned_model = AutoModelForCausalLM.from_pretrained("/content/ntwst-krisha")
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     835                     config = AutoConfig.for_model(**config_dict)
#     836                 else:
# --> 837                     config = AutoConfig.from_pretrained(
#     838                         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     839                     )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     932         code_revision = kwargs.pop("code_revision", None)
#     933
# --> 934         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     935         has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     936         has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     630         original_kwargs = copy.deepcopy(kwargs)
#     631         # Get config dict associated with the base config file
# --> 632         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     633         if "_commit_hash" in config_dict:
#     634             original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     687             try:
#     688                 # Load from local folder or from cache or download from model Hub and cache
# --> 689                 resolved_config_file = cached_file(
#     690                     pretrained_model_name_or_path,
#     691                     configuration_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     368         if not os.path.isfile(resolved_file):
#     369             if _raise_exceptions_for_missing_entries:
# --> 370                 raise EnvironmentError(
#     371                     f"{path_or_repo_id} does not appear to have a file named {full_filename}. Checkout "
#     372                     f"'https://huggingface.co/{path_or_repo_id}/tree/{revision}' for available files."
#
# OSError: /content/ntwst-krisha does not appear to have a file named config.json. Checkout 'https://huggingface.co//content/ntwst-krisha/tree/None' for available files.

# %%
encoded_inp = finetuned_tokenizer("Hello, how are you?", return_tensors="pt")
output = finetuned_model.generate(encoded_inp, max_new_tokens=100)
print(finetuned_tokenizer.decode(output[0], skip_special_tokens=True))

# %%
# !pip install trl
# Out:
# Collecting trl
#   Downloading trl-0.8.6-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.3.0+cu121)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from trl) (4.41.0)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl) (1.25.2)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 9.2 MB/s eta 0:00:00
# Collecting datasets (from trl)
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.6 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.4-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->trl)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->trl)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->trl)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.4.0->trl)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.23.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->trl) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->trl)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (2.0.3)
# Collecting xxhash (from datasets->trl)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->trl)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Installing collected packages: xxhash, shtab, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, nvidia-cusolver-cu12, datasets, accelerate, trl
# Successfully installed accelerate-0.30.1 datasets-2.19.1 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 shtab-1.7.1 trl-0.8.6 tyro-0.8.4 xxhash-3.4.1

# %%
from trl import SFTTrainer

# dataset = load_dataset("imdb", split="train")

trainer = SFTTrainer(
    "meta-llama/Llama-2-7b-chat-hf",
    train_dataset='/content/train.csv',
    dataset_text_field="text",
    packing=False,
    max_seq_length=512,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:166: UserWarning: You passed a model_id to the SFTTrainer. This will automatically create an `AutoModelForCausalLM` or a `PeftModel` (if you passed a `peft_config`) for you.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     398         # Load from URL or cache if already cached
# --> 399         resolved_file = hf_hub_download(
#     400             path_or_repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1220     else:
# -> 1221         return _hf_hub_download_to_cache_dir(
#    1222             # Destination
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1324         # Otherwise, raise appropriate error
# -> 1325         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1326
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1822         # Repo not found or gated => let's raise the actual error
# -> 1823         raise head_call_error
#    1824     else:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, local_files_only, relative_filename, storage_folder)
#    1721             try:
# -> 1722                 metadata = get_hf_file_metadata(url=url, proxies=proxies, timeout=etag_timeout, headers=headers)
#    1723             except EntryNotFoundError as http_error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1644     # Retrieve metadata
# -> 1645     r = _request_wrapper(
#    1646         method="HEAD",
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     371     if follow_relative_redirects:
# --> 372         response = _request_wrapper(
#     373             method=method,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     395     response = get_session().request(method=method, url=url, **params)
# --> 396     hf_raise_for_status(response)
#     397     return response
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     320             )
# --> 321             raise GatedRepoError(message, response) from e
#     322
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-66541802-3593d6d270932fc238dbe055;e3310649-20a2-4c2b-8941-de78a89fe9fa)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted. You must be authenticated to access it.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-3446d1c81cc6> in <cell line: 5>()
#       3 # dataset = load_dataset("imdb", split="train")
#       4
# ----> 5 trainer = SFTTrainer(
#       6     "meta-llama/Llama-2-7b-chat-hf",
#       7     train_dataset='/content/train.csv',
#
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py in __init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     168                 "`AutoModelForCausalLM` or a `PeftModel` (if you passed a `peft_config`) for you."
#     169             )
# --> 170             model = AutoModelForCausalLM.from_pretrained(model, **model_init_kwargs)
#     171
#     172         if packing and data_collator is not None and isinstance(data_collator, DataCollatorForCompletionOnlyLM):
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     521                 _ = kwargs.pop("quantization_config")
#     522
# --> 523             config, kwargs = AutoConfig.from_pretrained(
#     524                 pretrained_model_name_or_path,
#     525                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     932         code_revision = kwargs.pop("code_revision", None)
#     933
# --> 934         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     935         has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     936         has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     630         original_kwargs = copy.deepcopy(kwargs)
#     631         # Get config dict associated with the base config file
# --> 632         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     633         if "_commit_hash" in config_dict:
#     634             original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     687             try:
#     688                 # Load from local folder or from cache or download from model Hub and cache
# --> 689                 resolved_config_file = cached_file(
#     690                     pretrained_model_name_or_path,
#     691                     configuration_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     415         if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     416             return resolved_file
# --> 417         raise EnvironmentError(
#     418             "You are trying to access a gated repo.\nMake sure to have access to it at "
#     419             f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-chat-hf.
# 401 Client Error. (Request ID: Root=1-66541802-3593d6d270932fc238dbe055;e3310649-20a2-4c2b-8941-de78a89fe9fa)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted. You must be authenticated to access it.

# %%
from transformers import AutoModelForCausalLM
from datasets import load_dataset
from trl import SFTTrainer

dataset = load_dataset("imdb", split="train")

model = AutoModelForCausalLM.from_pretrained("facebook/opt-350m")

trainer = SFTTrainer(
    model,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=512,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
trainer.train()

# %%
trainer.save_model(f'sft_trainer2')
